# %%
x = 5
print("x is of type:",type(x))
y = 3.4
print("y is of type:",type(y))
x = x + y
print(x)
print("x is of type:",type(x))
# Out:
# x is of type: <class 'int'>
# y is of type: <class 'float'>
# 8.4
# x is of type: <class 'float'>

# %%
#initializing  string
s = "1010"
# printing string converting to float
e = float(s)
print ("After converting to float : ", end="")
print (e)
# printing string converting to int base 2
c = int(s,2)
print ("After converting to integer base 2 : ", end="")
print (c)
s="a"
c = ord(s)
print ("After converting character to integer : ",end="")
print (c)
# Out:
# After converting to float : 1010.0
# After converting to integer base 2 : 10
# After converting character to integer : 97

# %%
# Convert ASCII value to characters
a = chr(99)
b = chr(67)
print(a)
print(b)
# Out:
# c
# C

# %%
# printing integer converting to hexadecimal string
c = hex(10)
print ("After converting 10 to hexadecimal string : ",end="")
print (c)
# Out:
# After converting 10 to hexadecimal string : 0xa

# %%
# printing integer converting to octal string
c = oct(10)
print ("After converting 10 to octal string : ",end="")
print (c)
# Out:
# After converting 10 to octal string : 0o12

# %%
s = 'mit'
# printing string converting to tuple
c = tuple(s)
print ("After converting string to tuple : ",end="")
print (c)
# printing string converting to set
c = set(s)
print ("After converting string to set : ",end="")
print (c)
# printing string converting to list
c = list(s)
print (
"After converting string to list : "
,end=
""
)
print (c)
# Out:
# After converting string to tuple : ('m', 'i', 't')
# After converting string to set : {'i', 'm', 't'}
# After converting string to list : ['m', 'i', 't']

# %%
#string functions
var =
'PYTHON INTERPRETER'
print (var.capitalize())
var ='MitPolytechnic'
print (var.lower())
print (var.upper())
print (var.swapcase())
var ='welcome to Python programming'
print (var.title())
var='Python'
print (var.islower())
var='PYTHON'
print (var.isupper())
print ('2'.isdigit())
#find(str [,i [,j]])
var=
"Mit Polytechnic"
str
=
"oly"
print (
"\n"
,var.find(
str
))
# Finds the starting position of str
var=
"Mit Polytechnic"
str
=
"Poly"
print (var.find(
str
,
3
,
9
))
#Finds the string between position 3 to 9
var=
'That is a good example'
str
=
'was'
print (
"\n"
,var.replace(
'is'
,
str
))
var ="This is a good example"
print ("\n",var.split())
var=
#Print new line\nNextline\nMove again to new line'
print (var.splitlines())
seq=('ab','bc','cd')
str='+'
print (str.join(seq),"\n")
# Out:
#   File "/tmp/ipykernel_493/2430057850.py", line 2
#     var =
#          ^
# SyntaxError: invalid syntax

# %%
# Python code to demonstrate the working of
# ceil() and floor()
# importing "math" for mathematical operations
import math
from
math
import factorial,gcd
a =2.3
print (
"The ceil of 2.3 is : "
, end=
""
)
print (math.ceil(a))
print (
"The floor of 2.3 is : "
, end=
""
)
print (math.floor(a))
a=
5
b=
2
print (
"The power of 5 to 2 is : "
, end=
""
)
print (math.
pow
(a,b))
a=
5
print (
"The factorial of 5 is : "
, end=
""
)
print (math.factorial(a))
a=
5
b=
15
print (
"The gcd of 5 and 15 is : "
, end=
""
)
print (math.gcd(
5
,
15
))

# %%
# Def Function name(parameters) :
#statements
#
def fun() :
  print("Wlcome to MIT")
fun()
# Out:
# Wlcome to MIT

# %%
def evenOdd (x) :
  if x % 2 == 0 :
    return "Even"
  else :
    return "Odd"
print(evenOdd(2))
# Out:
# Even

# %%
def myfun(x, y =50) : #Default arguements
  print(x)
  print(y)
  return
myfun(10)
# Out:
# 10
# 50

# %%
def greet (name = "MIT") :
  print("Hello", name)

greet ("Lavkesh")
# Out:
# Hello Lavkesh

# %%
# Positional Arguements :
def Student (p1 ,)

# %%
#Fibonacci with factorials
def fact(x) :
  if x == 1 :
     return 1
  elif x == 0 :
    return 0
  else :
    return
    i  = i +1
